# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
auto=pd.read_csv('https://raw.githubusercontent.com/fenago/DSBook/main/Chapter%2010%20-%20Analyzing%20a%20Dataset/Datasets/Automobile_data.csv')
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Categorical

# %%
#number of unique styles
auto['body-style'].nunique()
# Out:
# 5

# %%
#show unique values
auto['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
#how many do we have of each one of these subcategories
auto['body-style'].value_counts(dropna=False,normalize=True)
# Out:
# sedan          0.468293
# hatchback      0.341463
# wagon          0.121951
# hardtop        0.039024
# convertible    0.029268
# Name: body-style, dtype: float64

# %%
auto.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
# !pip install altair
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ...
#      |████████████████████████████████| 812 kB 15.6 MB/s eta 0:00:01
# ...

# %%
import altair as alt

# %%
sample_df=auto.sample(n=50,random_state=10)

# %%
base = alt.Chart(sample_df)

# %%
chart = base.mark_circle()

# %%
chart.encode(x='curb-weight', y='highway-mpg')
#bivariate - comparing 2 variablesalt.Chart(sample_df).mark_circle().encode(x='curb-weight',y='highway-mpg',color='num-of-cylinders')
# Out:
# alt.Chart(...)

# %%
alt.Chart(sample_df).mark_circle().encode(x='curb-weight',y='highway-mpg',color='num-of-cylinders')
#multivariate analysis
# Out:
# alt.Chart(...)

# %%
alt.Chart(sample_df).mark_bar().encode(alt.X('highway-mpg:Q',bin=True),y='count()')
# Out:
# alt.Chart(...)
